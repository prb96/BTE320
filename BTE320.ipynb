# %% [markdown]
# <a href="https://colab.research.google.com/github/prb96/BTE320/blob/main/BTE320.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
x=2

# %%
x = 3
